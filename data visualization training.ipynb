# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows",1000000)
from pylab import mpl,plt

# %%
plt.style.use('seaborn')
mpl.rcParams['font.family']='serif'
# %matplotlib inline
# Out:
# C:\Users\matty\AppData\Local\Temp\ipykernel_14620\1919144535.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
import yfinance
import datetime as dt

# %%
start=dt.datetime(2021,1,1)
end=dt.datetime(2024,1,1)
data1=yfinance.download('NQ=F',start,end)
data1
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open         High       Low         Close     Adj Close  \
# Date
# 2021-01-04  12889.00  12959.75000  12522.50  12685.500000  12685.500000
# 2021-01-05  12682.75  12809.00000  12612.00  12793.500000  12793.500000
# 2021-01-06  12800.25  12844.25000  12491.25  12616.750000  12616.750000
# 2021-01-07  12658.50  12959.00000  12646.50  12928.000000  12928.000000
# 2021-01-08  12927.00  13125.00000  12919.00  13097.250000  13097.250000
# 2021-01-11  13093.25  13105.25000  12871.75  12897.000000  12897.000000
# 2021-01-12  12910.75  12959.00000  12767.25  12890.250000  12890.250000
# 2021-01-13  12882.50  13003.00000  12820.75  12972.250000  12972.250000
# 2021-01-14  12975.50  13028.75000  12881.00  12901.000000  12901.000000
# 2021-01-15  12909.00  12931.25000  12743.50  12802.250000  12802.250000
# 2021-01-19  12774.25  13032.75000  12727.00  12985.500000  12985.500000
# ...

# %%
d1=data1['Adj Close']
d1
# Out:
# Date
# 2021-01-04    12685.500000
# 2021-01-05    12793.500000
# 2021-01-06    12616.750000
# 2021-01-07    12928.000000
# 2021-01-08    13097.250000
# 2021-01-11    12897.000000
# 2021-01-12    12890.250000
# 2021-01-13    12972.250000
# 2021-01-14    12901.000000
# 2021-01-15    12802.250000
# 2021-01-19    12985.500000
# 2021-01-20    13294.250000
# 2021-01-21    13395.500000
# 2021-01-22    13361.500000
# 2021-01-25    13475.500000
# 2021-01-26    13485.500000
# 2021-01-27    13105.500000
# 2021-01-28    13186.000000
# 2021-01-29    12911.250000
# 2021-02-01    13236.500000
# 2021-02-02    13449.000000
# 2021-02-03    13394.250000
# 2021-02-04    13547.500000
# 2021-02-05    13598.000000
# 2021-02-08    13683.000000
# 2021-02-09    13680.250000
# 2021-02-10    13643.500000
# 2021-02-11    13729.000000
# 2021-02-12    13804.750000
# 2021-02-16    13767.750000
# 2021-02-17    13699.750000
# 2021-02-18    13633.000000
# 2021-02-19    13576.000000
# 2021-02-22    13224.250000
# ...

# %%
data2=yfinance.download('ES=F',start,end)
d2=data2['Adj Close']
d2
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2021-01-04    3692.250000
# 2021-01-05    3718.250000
# 2021-01-06    3740.500000
# 2021-01-07    3795.500000
# 2021-01-08    3817.500000
# 2021-01-11    3792.000000
# 2021-01-12    3794.500000
# 2021-01-13    3803.750000
# 2021-01-14    3791.250000
# 2021-01-15    3762.250000
# 2021-01-19    3790.500000
# 2021-01-20    3845.000000
# 2021-01-21    3846.000000
# 2021-01-22    3834.250000
# 2021-01-25    3848.500000
# 2021-01-26    3842.500000
# 2021-01-27    3744.250000
# 2021-01-28    3779.250000
# 2021-01-29    3705.250000
# 2021-02-01    3765.750000
# 2021-02-02    3818.250000
# 2021-02-03    3823.500000
# 2021-02-04    3864.500000
# 2021-02-05    3880.250000
# 2021-02-08    3908.000000
# 2021-02-09    3905.500000
# 2021-02-10    3903.000000
# 2021-02-11    3912.000000
# 2021-02-12    3931.000000
# 2021-02-16    3927.750000
# 2021-02-17    3928.000000
# 2021-02-18    3909.500000
# ...

# %%
data3=yfinance.download('YM=F',start,end)
d3=data3['Adj Close']
d3
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2021-01-04    30104.000000
# 2021-01-05    30285.000000
# 2021-01-06    30720.000000
# 2021-01-07    30942.000000
# 2021-01-08    30993.000000
# 2021-01-11    30902.000000
# 2021-01-12    30974.000000
# 2021-01-13    30959.000000
# 2021-01-14    30909.000000
# 2021-01-15    30720.000000
# 2021-01-19    30828.000000
# 2021-01-20    31096.000000
# 2021-01-21    31082.000000
# 2021-01-22    30909.000000
# 2021-01-25    30868.000000
# 2021-01-26    30842.000000
# 2021-01-27    30189.000000
# 2021-01-28    30507.000000
# 2021-01-29    29879.000000
# 2021-02-01    30110.000000
# 2021-02-02    30586.000000
# 2021-02-03    30627.000000
# 2021-02-04    30950.000000
# 2021-02-05    31042.000000
# 2021-02-08    31268.000000
# 2021-02-09    31278.000000
# 2021-02-10    31328.000000
# 2021-02-11    31359.000000
# 2021-02-12    31397.000000
# 2021-02-16    31458.000000
# 2021-02-17    31549.000000
# ...

# %%
plt.plot(d1)

# %%
plt.plot(d1.cumsum())

# %%
plt.plot(d2,'r')
plt.grid(False)
plt.axis('tight')
plt.xlabel('DATA')
plt.ylabel('SEP500')
plt.title('prezzo sep500')
# Out:
# Text(0.5, 1.0, 'prezzo sep500')

# %%
plt.plot(d3,'y',lw=1,ls='--')

# %%
plt.plot(d1)
plt.plot(d2)
plt.plot(d3)

# %%
r1=d1.pct_change()
r2=d2.pct_change()
r3=d3.pct_change()

# %%
plt.subplot(121)
plt.plot(r1)
plt.subplot(122)
plt.plot(r3)

# %%
# !pip install quandl

# %%
# !pip install pandas_datareader

# %%
import pandas_datareader as pdr
import datetime as dt

# Imposta la data di inizio e di fine per il periodo di tempo desiderato
start = dt.datetime(2021, 1, 1)
end = dt.datetime(2024, 1, 1)

# Scarica i dati sull'inflazione (Consumer Price Index) dagli Stati Uniti da FRED
cpi = pdr.get_data_fred('CPIAUCSL', start, end)

print(cpi)
# Out:
#             CPIAUCSL
# DATE
# 2021-01-01   262.518
# 2021-02-01   263.583
# 2021-03-01   264.910
# 2021-04-01   266.752
# 2021-05-01   268.452
# 2021-06-01   270.664
# 2021-07-01   271.994
# 2021-08-01   272.789
# 2021-09-01   273.887
# 2021-10-01   276.434
# 2021-11-01   278.799
# 2021-12-01   280.808
# 2022-01-01   282.390
# 2022-02-01   284.535
# 2022-03-01   287.553
# 2022-04-01   288.764
# 2022-05-01   291.359
# 2022-06-01   294.996
# 2022-07-01   294.977
# 2022-08-01   295.209
# 2022-09-01   296.341
# 2022-10-01   297.863
# 2022-11-01   298.648
# 2022-12-01   298.812
# 2023-01-01   300.356
# 2023-02-01   301.509
# 2023-03-01   301.744
# 2023-04-01   303.032
# 2023-05-01   303.365
# 2023-06-01   304.003
# 2023-07-01   304.628
# 2023-08-01   306.187
# 2023-09-01   307.288
# 2023-10-01   307.531
# 2023-11-01   308.024
# 2023-12-01   308.742
# 2024-01-01   309.685

# %%
usaCPI=pd.DataFrame(cpi)

# %%
usaCPI
# Out:
#             CPIAUCSL
# DATE
# 2021-01-01   262.518
# 2021-02-01   263.583
# 2021-03-01   264.910
# 2021-04-01   266.752
# 2021-05-01   268.452
# 2021-06-01   270.664
# 2021-07-01   271.994
# 2021-08-01   272.789
# 2021-09-01   273.887
# 2021-10-01   276.434
# 2021-11-01   278.799
# 2021-12-01   280.808
# 2022-01-01   282.390
# 2022-02-01   284.535
# 2022-03-01   287.553
# 2022-04-01   288.764
# 2022-05-01   291.359
# 2022-06-01   294.996
# 2022-07-01   294.977
# 2022-08-01   295.209
# 2022-09-01   296.341
# 2022-10-01   297.863
# 2022-11-01   298.648
# 2022-12-01   298.812
# 2023-01-01   300.356
# 2023-02-01   301.509
# 2023-03-01   301.744
# 2023-04-01   303.032
# 2023-05-01   303.365
# 2023-06-01   304.003
# 2023-07-01   304.628
# 2023-08-01   306.187
# 2023-09-01   307.288
# 2023-10-01   307.531
# 2023-11-01   308.024
# 2023-12-01   308.742
# 2024-01-01   309.685

# %%
d11=pd.DataFrame(d1)
d11
# Out:
#                Adj Close
# Date
# 2021-01-04  12685.500000
# 2021-01-05  12793.500000
# 2021-01-06  12616.750000
# 2021-01-07  12928.000000
# 2021-01-08  13097.250000
# 2021-01-11  12897.000000
# 2021-01-12  12890.250000
# 2021-01-13  12972.250000
# 2021-01-14  12901.000000
# 2021-01-15  12802.250000
# 2021-01-19  12985.500000
# 2021-01-20  13294.250000
# 2021-01-21  13395.500000
# 2021-01-22  13361.500000
# 2021-01-25  13475.500000
# 2021-01-26  13485.500000
# 2021-01-27  13105.500000
# 2021-01-28  13186.000000
# 2021-01-29  12911.250000
# 2021-02-01  13236.500000
# 2021-02-02  13449.000000
# 2021-02-03  13394.250000
# 2021-02-04  13547.500000
# 2021-02-05  13598.000000
# 2021-02-08  13683.000000
# 2021-02-09  13680.250000
# 2021-02-10  13643.500000
# 2021-02-11  13729.000000
# 2021-02-12  13804.750000
# 2021-02-16  13767.750000
# 2021-02-17  13699.750000
# 2021-02-18  13633.000000
# 2021-02-19  13576.000000
# 2021-02-22  13224.250000
# 2021-02-23  13192.000000
# ...

# %%
plt.hist(r1,bins=200);

# %%
import cufflinks as cf
import plotly.offline as plyo
plyo.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
plyo.iplot(d1.iplot(asFigure=True),image='png',filename='ply_01')
plyo.iplot(d3.iplot(asFigure=True),image='png',filename='ply_01')
# Out:
# <div>                            <div id="a03b1d0a-6e49-4821-9624-475aaed6bbf0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a03b1d0a-6e49-4821-9624-475aaed6bbf0")) {                    Plotly.newPlot(                        "a03b1d0a-6e49-4821-9624-475aaed6bbf0",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"Adj Close","text":"","x":["2021-01-04","2021-01-05","2021-01-06","2021-01-07","2021-01-08","2021-01-11","2021-01-12","2021-01-13","2021-01-14","2021-01-15","2021-01-19","2021-01-20","2021-01-21","2021-01-22","2021-01-25","2021-01-26","2021-01-27","2021-01-28","2021-01-29","2021-02-01","2021-02-02","2021-02-03","2021-02-04","2021-02-05","2021-02-08","2021
# ...

# %%
result=pd.merge(d1,d3,on='Date')
result.columns=['nasdaq','dowjones']
result
# Out:
#                   nasdaq      dowjones
# Date
# 2021-01-04  12685.500000  30104.000000
# 2021-01-05  12793.500000  30285.000000
# 2021-01-06  12616.750000  30720.000000
# 2021-01-07  12928.000000  30942.000000
# 2021-01-08  13097.250000  30993.000000
# 2021-01-11  12897.000000  30902.000000
# 2021-01-12  12890.250000  30974.000000
# 2021-01-13  12972.250000  30959.000000
# 2021-01-14  12901.000000  30909.000000
# 2021-01-15  12802.250000  30720.000000
# 2021-01-19  12985.500000  30828.000000
# 2021-01-20  13294.250000  31096.000000
# 2021-01-21  13395.500000  31082.000000
# 2021-01-22  13361.500000  30909.000000
# 2021-01-25  13475.500000  30868.000000
# 2021-01-26  13485.500000  30842.000000
# 2021-01-27  13105.500000  30189.000000
# 2021-01-28  13186.000000  30507.000000
# 2021-01-29  12911.250000  29879.000000
# 2021-02-01  13236.500000  30110.000000
# 2021-02-02  13449.000000  30586.000000
# 2021-02-03  13394.250000  30627.000000
# 2021-02-04  13547.500000  30950.000000
# ...

# %%
plyo.iplot(result.iplot(asFigure=True),image='png',filename='ply_01')
xTitle='date'
title= 'time series plot'
# Out:
# <div>                            <div id="d0ffda3d-4095-4726-8048-e09bce3c276e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0ffda3d-4095-4726-8048-e09bce3c276e")) {                    Plotly.newPlot(                        "d0ffda3d-4095-4726-8048-e09bce3c276e",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"nasdaq","text":"","x":["2021-01-04","2021-01-05","2021-01-06","2021-01-07","2021-01-08","2021-01-11","2021-01-12","2021-01-13","2021-01-14","2021-01-15","2021-01-19","2021-01-20","2021-01-21","2021-01-22","2021-01-25","2021-01-26","2021-01-27","2021-01-28","2021-01-29","2021-02-01","2021-02-02","2021-02-03","2021-02-04","2021-02-05","2021-02-08","2021-02
# ...

# %%
d111=cf.QuantFig(d1,title='nasdaq prezzi',legend='top',name='nasdaq')

# %%
d111.add_bollinger_bands(periods=15,boll_std=2)

# %%
nasdaq=yfinance.download('NQ=F',start,end)
nasdaq
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open         High       Low         Close     Adj Close  \
# Date
# 2021-01-04  12889.00  12959.75000  12522.50  12685.500000  12685.500000
# 2021-01-05  12682.75  12809.00000  12612.00  12793.500000  12793.500000
# 2021-01-06  12800.25  12844.25000  12491.25  12616.750000  12616.750000
# 2021-01-07  12658.50  12959.00000  12646.50  12928.000000  12928.000000
# 2021-01-08  12927.00  13125.00000  12919.00  13097.250000  13097.250000
# 2021-01-11  13093.25  13105.25000  12871.75  12897.000000  12897.000000
# 2021-01-12  12910.75  12959.00000  12767.25  12890.250000  12890.250000
# 2021-01-13  12882.50  13003.00000  12820.75  12972.250000  12972.250000
# 2021-01-14  12975.50  13028.75000  12881.00  12901.000000  12901.000000
# 2021-01-15  12909.00  12931.25000  12743.50  12802.250000  12802.250000
# 2021-01-19  12774.25  13032.75000  12727.00  12985.500000  12985.500000
# ...

# %%
qf=cf.QuantFig(nasdaq, title='nasdaq prezzi',legend='top',name='nasdaq')
qf.add_bollinger_bands(periods=15,boll_std=2.5)

# %%
plyo.iplot(qf.iplot(asFigure=True),image='png',filename='bollingher nasdaq')
# Out:
# <div>                            <div id="75c6080f-6a58-43a5-82bf-bd7fb7a2d0e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75c6080f-6a58-43a5-82bf-bd7fb7a2d0e8")) {                    Plotly.newPlot(                        "75c6080f-6a58-43a5-82bf-bd7fb7a2d0e8",                        [{"legendgroup":"BOLL(Close,15)","line":{"color":"rgba(55, 128, 191, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"BOLL(Close,15)","showlegend":true,"text":"","x":["2021-01-04","2021-01-05","2021-01-06","2021-01-07","2021-01-08","2021-01-11","2021-01-12","2021-01-13","2021-01-14","2021-01-15","2021-01-19","2021-01-20","2021-01-21","2021-01-22","2021-01-25","2021-01-26","2021-01-27","2021-01-28","2021-01-29","2021-02-01","2021-02-02","20
# ...

# %%
qf.add_rsi(periods=14,showbands=True)

# %%
plyo.iplot(qf.iplot(asFigure=True),image='png',filename='file_2')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 plyo.iplot(qf.iplot(asFigure=True),image='png',filename='file_2')
#
# File ~\anaconda3\Lib\site-packages\cufflinks\quant_figure.py:1235, in QuantFig.iplot(self, **kwargs)
#    1233 kwargs.update(slice=_slice,resample=_resample)
#    1234 for k,v in list(self.studies.items()):
# -> 1235 	study_fig=self._get_study_figure(k,**kwargs)
#    1236 	study_fig=tools.fig_to_dict(study_fig)
#    1237 	if 'yaxis' in study_fig['layout']:
#
# File ~\anaconda3\Lib\site-packages\cufflinks\quant_figure.py:1086, in QuantFig._get_study_figure(self, study_id, **kwargs)
#    1084 	locals_list=['rsi_lower','rsi_upper','showbands']
#    1085 	local_kwargs,params=get_params(locals_list,params,display)
# -> 1086 	fig=df.ta_figure(study=kind,**params)
#    1087 	# del fig.layout['shapes']
# ...
